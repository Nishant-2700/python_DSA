# %%
#retrun the last index of integer x present in the array ( use indexing)


def lastindexbetter(arr,x,si):
    if si == len(arr):
        return -1
    smalloutput = lastindexbetter(arr, x, si + 1)

    if smalloutput != -1:
        return smalloutput

    if arr[si] == x:
        return si
    else:
        return -1


arr = [2,5,3,6,2,5,8,5,6,5,5,6,7,9]
x = 
si =0
print(lastindexbetter(arr,x,si))
# Out:
# -1

# %%
def ifpresent(s,ch):
    if ch in s:
        return True
    return False
        

s = "abcdef"
ch = 's'
print(ifpresent(s,ch))
# Out:
# False
