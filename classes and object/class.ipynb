# %%
class student:
    passingpercentage = 40
    def studentdetails(self):
        self.name= "Nishant"
        print("Name =" ,self.name)
        self.percentage =60
        print("Percentage =",self.percentage)
    def ispassed(self):
        if self.percentage> student.passingpercentage:
            print("student is Passed")
        else:
            print("Student id not passed")

s1 = student()
s1.studentdetails()
s1.ispassed()
student.studendetails(s1)
# Out:
# Name = Nishant
# Percentage = 60
# student is Passed
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 17
#      15 s1.studentdetails()
#      16 s1.ispassed()
# ---> 17 student.studendetails(s1)
#
# AttributeError: type object 'student' has no attribute 'studendetails'
