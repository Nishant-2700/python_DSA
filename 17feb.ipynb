# %%
#Stack (LIFO)
#pop - removing the top element using pop function
#push - inserting element in last using append funtion
#Top - get the top / last element [len(l)-1]
#size - total element(len(list))
#isempty - stack? if len(s) ==0?

# %%
stack =[]
stack.append(10)
stack.append(20)
stack.append(2)
stack.append(55)
stack.append(85)
print(stack)
# Out:
# [10, 20, 2, 55, 85]

# %%
stack.pop()
print(stack)
# Out:
# [10, 20]

# %%
stack[-1]
# Out:
# 55

# %%
len(stack)==0
# Out:
# False

# %%
#valid parantheses
