# %%
a = int(input("Enter a number"))
b = int(input("Enter a number"))
ans = 0
minvalue = min(a,b)
for i in range(minvalue+1,0,-1):
    if (a%i==0) and (b%i==0):
        ans = i
        break
print(ans)

# %%
a = int(input("Enter number: "))
b = int(input("Enter number: "))
lcm =1
maxvalue = max(a, b)
minvalue = a *b 
for i in range(maxvalue,minvalue+1):
    if i % a == 0 and i % b== 0:
        lcm = i
        break
print(lcm)
# Out:
# Enter number:  12
# Enter number:  18
# 36

# %%
#Given 2 positive numbers, find GCD or HCF of both the numbers.

a = int(input("Enter a number"))
b = int(input("Enter a number"))
ans = 0
for i in range(1,max(a,b)+1):
    if (a%i==0) and (b%i==0):
     ans = i
print(ans)
# Out:
# Enter a number 12
# Enter a number 18
# 6

# %%
#Given temperature of person, analyse the situation of person and give him advice.

Temp = float(input("Enter the temperature of Person"))
if (85.0<=Temp<=91.0):
    print("Serious Hypothermia")
elif(91.0<Temp<=95.0):
    print("Mild Hypothermia")
elif (95.0<Temp<=98.0):
    print("Normal Temprature")
elif(98.0<Temp<=100.0):
    print("Mild Fever")
elif(100.0<Temp<=105.0):
    print("High Fever")
else:
    print("Temprature is out of range")
# Out:
# Enter the temperature of Person 105
# High Fever

# %%
#Check whether a given number is positive-odd, positive-even, negative-odd OR negative-even.

num = int(input("Enter a number"))

if num >0:
    if num%2==0:
        print("Number is positive and even")
    else:
        print("Number is positive and odd")
if num<0:
    if num%2==0:
        print("Number is Negative and even")
    else:
        print("Number is Negative and odd")
# Out:
# Enter a number 25
# Number is positive ans odd

# %%
#Write a program that takes a positive integer N as input from the user and prints all natural numbers from 1 to N, 

#for loop
# num =int(input("Enter a number"))
# for i in range(1,num+1):
#     print(i,end = " ")

#while loop
# num =int(input("Enter a number"))
# i=1
# while(i<=num):
#     print(i,end=" ")
#     i=i+1
# Out:
# Enter a number 5
# 1 2 3 4 5

# %%
#Given a number N, Print all digits of number (from right to left) in new line.

# num =(input("Enter a number"))
# for digit in num[::-1]:
#     print(digit)



num=int(input("Enter a number"))
while num>0:
    digit=num%10
    print(digit)
    num = num//10
# Out:
# Enter a number 1425
# 5
# 2
# 4
# 1

# %%
#Given a positive number, print all the factors of that number till n.
num = int(input("Enter a number"))
for i in range(1,num+1):
    if num%i==0:
        print(i)



# num = int(input("Enter a number: "))
# for i in range(1, int(num**0.5) + 1):
#     if num % i == 0:
#         print(i)
#         if i != num // i:
#             print(num // i)
# Out:
# Enter a number 25
# 1
# 5
# 25

# %%
#Given a positive number, print the count of the factors of that number.

num = int(input("Enter a number"))
count = 0
for i in range(1,num+1):
    if num%i==0:
        count=count+1

print(count)
# Out:
# Enter a number 25
# 3

# %%
#WAP to tell if the input number is Prime or not.

num = int(input("Enter a number"))
for i in range(2,num):
    if num%i==0:
        print(num,"is Not a prime number")
        break
else:
    print(num,"is a Prime number")
# Out:
# Enter a number 31
# 31 is a Prime number
