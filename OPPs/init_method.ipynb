# %%
class Student():
    def __init__(self, name = 'default name', rollNumber ='default rollno'):                     # Assigning values to all the objects
        self.name = name
        self.rollNumber = rollNumber

# %%
s1 = Student("Ram", '01')
s1.__dict__
# Out:
# {'name': 'Ram', 'rollNumber': '01'}

# %%
s2 = Student()
s2.__dict__
# Out:
# {'name': 'default name', 'rollNumber': 'default rollno'}

# %%
s3 = Student('Rahul', 34)

# %%
s3.__dict__
# Out:
# {'name': 'Rahul', 'rollNumber': 34}
