# %%
class student:
    pass

# %%
s1 = student()
print(type(s1))
# Out:
# <class '__main__.student'>

# %%
s2 = student()
s3 = student()

# %%
print(s2,s3)
# Out:
# <__main__.student object at 0x0000012E5A8EDBD0> <__main__.student object at 0x0000012E5A6CF950>

# %%
#Assigning Values to Object

s1.name = 'Nishant'
s2.name = 'Roshan'
s1.rollNumber = 33
s2.rollNumber = 55

# %% [raw]
# print(s2.rollNumber)

# %%
print(s1.__dict__,s2.__dict__)
# Out:
# {'name': 'Nishant', 'rollNumber': 33} {'name': 'Roshan', 'rollNumber': 55}

# %%
s2.__dict__
# Out:
# {'name': 'Roshan', 'rollNumber': 55}

# %%
getattr(s1,'rollNumber')
# Out:
# 33

# %%
delattr(s2,'name')

# %%
s2.__dict__
# Out:
# {'rollNumber': 55}
