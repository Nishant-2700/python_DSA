# %%
#Functions

def sum(a,b,c):
    s=a+b+c
    return s

sum_of_three_no = sum(5,5,5)
print(sum_of_three_no)
# Out:
# 15

# %%
name = "   Nishant Gupta  "

print(name.strip())
# Out:
# Nishant Gupta

# %%
name = "Nishant Gupta"

"Nishant" in name
print(name[0::2])
# Out:
# True

# %%
name = "NISHANT GUPTA"
print(name.upper())
print(name.lower())
print(name.isupper())
print(name.islower())
# Out:
# NISHANT GUPTA
# nishant gupta
# True
# False

# %%
name = "Nishant Gupta"
print(name.find("ta"))
# Out:
# 11

# %%
name = "Nishant Gupta"
print(name.replace("Gupta","sharma"))
# Out:
# Nishant sharma

# %%
name = "Nishant Gupta"

for i in name:
    print(i)
# Out:
# N
# i
# s
# h
# a
# n
# t
#
# G
# u
# p
# t
# a

# %%
#Fibonacci

n = int(input("Enter number of terms: "))

a, b = 0, 1
print("Fibonacci series:")

for i in range(n):
    print(a, end=" ")
    a, b = b, a + b
# Out:
# Enter number of terms:  5
# Fibonacci series:
# 0 1 1 2 3

# %%
#Factorial

n = int(input("Enter a numnber"))
fact =1
for i in range(1,n+1):
    fact = fact*i
print("Factoria of",n,"is",fact)
# Out:
# Enter a numnber 6
# Factoria of 6 is 720

# %%
name = "Nishant Gupta"
c=0
for i in name:
    if i.isalpha() and i.lower()  not in "aeiou":
        c=c+1

print(c)


# name = "Nishant Gupta"
# c=0
# for i in name:
#     if i.lower()  in "aeiou":
#         c=c+1

# print(c)
# Out:
# 8

# %%
name = "Nishant152 Gupta"
c=0
for i in name:
    if i.isdigit():
        c=c+1

print(c)
# Out:
# 3

# %%
#Fibonacci

n = int(input("Enter number of terms: "))

a, b = 0, 1
print("Fibonacci series:")

for i in range(n):
    print(a, end=" ")
    a, b = b, a + b
# Out:
# Enter number of terms:  5
# Fibonacci series:
# 0 1 1 2 3

# %%
#palindrome string

str = "ABCDCBA"
rev=(str[::-1])
if rev==str:
    print("string is palindrom:")
else:
    print("string is not palindrome:")
# Out:
# string is not palindrome:

# %%
s = "ABCDCBA"
print(s.reverse())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 2
#       1 s = "ABCDCBA"
# ----> 2 print(s.reverse())
#
# AttributeError: 'str' object has no attribute 'reverse'

# %%
#Fibonacci

n = int (input("Enter a number"))
n1= 0
n2= 1
print(n1,end = " ")
print(n2,end = " ")
s =0
for i in range(3,n+1):
    s=n1+n2
    print(s,end = " ")
    n1=n2
    n2=s
# Out:
# Enter a number 6
# 0 1 1 2 3 5

# %%
n = int(input("Enter a number"))
fact =1
for i in range(1,n+1):
    fact = fact*i
print(fact)
