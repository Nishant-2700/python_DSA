# %%
def takeInput():
        # taking the space seperated input in a list
        inputList = [int(ele) for ele in input().split()]
        head = None
        #Traversing the List ending with -1
        for currData in inputList:
            if currData == -1:
                break
            # Creating a new Node and checking is it's head, if not, traversing the list to find the end and appending element
            newNode = Node(currData)
            if head is None:
                head = newNode
            else:
                curr = head
                while curr.next is not None:
                     curr.next = newNode
        return head
    
def printLL(head):
    while head is not None:
        print(str(head.data) + '->', end = '')
        head = head.next
    print('None')
    return

# %%
head = takeInput()
printLL(head)
# Out:
#  2 6 5 8 6 3
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 head = takeInput()
#       2 printLL(head)
#
# Cell In[6], line 10, in takeInput()
#       8     break
#       9 # Creating a new Node and checking is it's head, if not, traversing the list to find the end and appending element
# ---> 10 newNode = Node(currData)
#      11 if head is None:
#      12     head = newNode
#
# NameError: name 'Node' is not defined
