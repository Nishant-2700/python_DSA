# %%
#sum of two numbers
a=int(input("Enter a firest number: "))
b=int(input("Enter a second number: "))
sum = a+b
print("sum is =",sum)
# Out:
# Enter a firest number:  5
# Enter a second number:  6
# sum is = 11

# %%
# Program to calculate area and perimeter of a rectangle

length = float(input("Enter length of the rectangle: "))
breadth = float(input("Enter breadth of the rectangle: "))

area = length * breadth
perimeter = 2 * (length + breadth)

print("Area of rectangle =", area)
print("Perimeter of rectangle =", perimeter)
# Out:
# Enter length of the rectangle:  6
# Enter breadth of the rectangle:  3
# Area of rectangle = 18.0
# Perimeter of rectangle = 18.0

# %%
#Data types
a=123
print(type(a))
# Out:
# <class 'int'>

# %%
s="name"
print(type(s))
# Out:
# <class 'str'>

# %%
b=5.6
print(type(b))
# Out:
# <class 'float'>

# %%
# Program to calculate surface area and volume of a cube

side = float(input("Enter the side of the cube: "))

surface_area = 6 * side * side
volume = side * side * side

print("Surface Area of cube =", surface_area)
print("Volume of cube =", volume)
# Out:
# Enter the side of the cube:  5
# Surface Area of cube = 150.0
# Volume of cube = 125.0
