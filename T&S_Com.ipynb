# %%
#Time and space Complexity

1.Time complexity != Time taken
2.T.C is a funtion which tells the rship. of how algo. is behaving as the input size is increasing.
__________________________________________________________________________________________________

# what do we consider about T.C:-

1.it gives ans for worst case senario
- O(n^3)
2.always look com. of larger data or infinie data
- Actual tme for smaller may or may not have higher complexities.
- But when the size of Algo is inc. that is what we need to consiader.
- i.e why we dont consider constant value.
3.Always ignore the less dominating terms.

    O(1)<O(logN)<O(rootn N)<O(N)<O(NlogN)<O(N^2)<O(N^3).....<O(2^n)<O(3^n).....<O(n^n)
____________________________________________________________________________________________________

#Big-O-Notation
    Def- this is Upper Bound/Worst case/Max n Time taken.
   - Math Exp:
   - lim         f(n)/g(n)   < infi
    n-->infi

#Omega Notation
 Def- this is lower bound/min n time /Best case scenerio.
       lim
       n-->infi   f(n)/g(n)   > 0
#Theta Notation
    Def- when upper & lower Bound are Same.
# Out:
#   File <string>:22
#     - Math Exp:
#                ^
# IndentationError: unindent does not match any outer indentation level

# %%
Space Com
1. Swap Two number
T.C - O(1)  S.C - O(1)
2.Sum of n Numbers
T.C - O(n)  S.C - O(n)
3. Sum of tow matrix
T.C - O(n^2) S.C - O(n^2)
4.Multiplication of 2 matrix
T.C O(n^3)  S.C - O(n^2)
5.for (i=0;i<n;i++) Same (for --- i--,i+=2)
T.C O(n) S.C - O(n)
6.for (i=0;i<n;i++)
T.C - O(logn with base2) 
7.for (i=0;i<n;i\2)
T.C - O(log n)
8.for i in rnage (n)
  for i in rnage (n)
T.C - O(n)

Bubble Sort T.C - O(n^2)
selction sort T.C - O(n^2)
Merge Sort T.C - O(nlogn)             Quick Sort o(nlogn) Heap sort O(nlogn)
Binary search T.C - O(log n with base 2)

# %%
def func(n):
    if n ==0:
        return n
    func(n-1)
    print (n)

func(5)
# Out:
# 1
# 2
# 3
# 4
# 5
